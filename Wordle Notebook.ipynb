# %%
# Local packages
import Classes.wordle_data as wd
import Tools.wordle_utils as wu

# %% [markdown]
# # Wordle Top Words

# %%
wdl = wd.Wordle()
wdl.set_data()
wu.list_top_wordle_words(wordle=wdl, show_words=False)
# Out:
# Number of top Wordle words 4214
# Number of eligible Wordle words: 15920

# %% [markdown]
# # Wordle Guess

# %%
# Clue = OWNER, Sat 9.7.24
wdl = wd.Wordle()
wdl.set_data()

# Guess #1
wdl.wordle_guess(guess_word='pound',
                 good_letters=['o', 'n'],
                 good_letters_bad_placement=[1, 3])
wu.wordle_solver(wordle=wdl)

# Guess #2
wdl.wordle_guess(guess_word='dawgs',
                 good_letters=['w'],
                 good_letters_bad_placement=[2])
wu.wordle_solver(wordle=wdl)

# Guess #3
wdl.wordle_guess(guess_word='known',
                 good_letters=['n', 'o', 'w', 'n'],
                 good_letters_bad_placement=[1, 2, 3, 4])
wu.wordle_solver(wordle=wdl)

# Guess #4
wdl.wordle_guess(guess_word='raven',
                 good_letters=['r', 'e', 'n'],
                 good_letters_bad_placement=[0, None, 4],
                 good_letters_good_placement=[None, 3, None])
wu.wordle_solver(wordle=wdl)

# Guess #5
wdl.wordle_guess(guess_word='owned',
                 good_letters=['o', 'w', 'n', 'e'],
                 good_letters_good_placement=[0, 1, 2, 3])
wu.wordle_solver(wordle=wdl)

# %%
# Clue = DRAWN, Sun 9.8.24
wdl = wd.Wordle()
wdl.set_data()

# Guess #1
wdl.wordle_guess(guess_word='ideas',
                 good_letters=['d', 'a'],
                 good_letters_bad_placement=[1, 3])
wu.wordle_solver(wordle=wdl)

# Guess #2
wdl.wordle_guess(guess_word='draft',
                 good_letters=['d', 'r', 'a'],
                 good_letters_good_placement=[0, 1, 2])
wu.wordle_solver(wordle=wdl)

# Guess #3
wdl.wordle_guess(guess_word='drawn',
                 good_letters=['d', 'r', 'a', 'w', 'n'],
                 good_letters_good_placement=[0, 1, 2, 3, 4])
wu.wordle_solver(wordle=wdl)

# %%
# Clue = DEBIT, Mon 9.9.24
wdl = wd.Wordle()
wdl.set_data()

# Guess #1
wdl.wordle_guess(guess_word='ideas',
                 good_letters=['i', 'd', 'e'],
                 good_letters_bad_placement=[0, 1, 2])
wu.wordle_solver(wordle=wdl)

# Guess #2
wdl.wordle_guess(guess_word='tried',
                 good_letters=['t', 'i', 'e', 'd'],
                 good_letters_bad_placement=[0, 2, 3, 4])
wu.wordle_solver(wordle=wdl)

# Guess #3
wdl.wordle_guess(guess_word='debit',
                 good_letters=['d', 'e', 'b', 'i', 't'],
                 good_letters_good_placement=[0, 1, 2, 3, 4])
wu.wordle_solver(wordle=wdl)

# %%
# Clue = REBEL, Tue 9.10.24
wdl = wd.Wordle()
wdl.set_data()

# Guess #1
wdl.wordle_guess(guess_word='ideas',
                 good_letters=['e'],
                 good_letters_bad_placement=[2])
wu.wordle_solver(wordle=wdl)

# Guess #2
# TODO Need to fix good letter bad placement based on this guess
wdl.wordle_guess(guess_word='cover',
                 good_letters=['e', 'r'],
                 good_letters_bad_placement=[None, 4],
                 good_letters_good_placement=[3, None])
wu.wordle_solver(wordle=wdl)

# Guess #3
wdl.wordle_guess(guess_word='threw',
                 good_letters=['e', 'r'],
                 good_letters_bad_placement=[None, 2],
                 good_letters_good_placement=[3, None])
wu.wordle_solver(wordle=wdl)

# Guess #4
wdl.wordle_guess(guess_word='green',
                 good_letters=['e', 'r'],
                 good_letters_bad_placement=[2, 1],
                 good_letters_good_placement=[3, None])
wu.wordle_solver(wordle=wdl)

# Guess #5
wdl.wordle_guess(guess_word='rebel',
                 good_letters=['r', 'e', 'b', 'e', 'l'],
                 good_letters_good_placement=[0, 1, 2, 3, 4])
wu.wordle_solver(wordle=wdl)

# %%
# Clue = BRASS, Thu 9.12.24
wdl = wd.Wordle()
wdl.set_data()

# Guess #1
wdl.wordle_guess(guess_word='adieu',
                 good_letters=['a'],
                 good_letters_bad_placement=[0])
wu.wordle_solver(wordle=wdl)

# Guess #2
wdl.wordle_guess(guess_word='woman',
                 good_letters=['a'],
                 good_letters_bad_placement=[3])
wu.wordle_solver(wordle=wdl)

# Guess #3
wdl.wordle_guess(guess_word='track',
                 good_letters=['r', 'a'],
                 good_letters_good_placement=[1, 2])
wu.wordle_solver(wordle=wdl)

# Guess #4
wdl.wordle_guess(guess_word='grass',
                 good_letters=['r', 'a', 's', 's'],
                 good_letters_good_placement=[1, 2, 3, 4])
wu.wordle_solver(wordle=wdl)

# Guess #5
wdl.wordle_guess(guess_word='brass',
                 good_letters=['b', 'r', 'a', 's', 's'],
                 good_letters_good_placement=[0, 1, 2, 3, 4])
wu.wordle_solver(wordle=wdl)
# Out:
# Number of top Wordle words 4214
# Number of eligible Wordle words: 15920
#
# Guess: adieu
# Good placement dictionary {}
# Bad placement dictionary {'a': [0]}
# Bad letters ['e', 'i', 'u', 'd']
# Top eligible word list:
# 1-14.) woman
# 1-26.) plant
# 1-36.) carry
# 1-41.) track
# 1-42.) plans
# 1-46.) plays
# 1-48.) stars
# 1-58.) match
# 1-69.) staff
# 1-74.) coast
# 1-88.) calls
# 1-101.) walls
# 1-107.) royal
# 1-110.) glass
# 1-134.) labor
# 1-142.) moral
# 1-147.) solar
# 1-161.) shall
# 1-181.) goals
# 1-183.) apart
# 1-214.) falls
# 1-219.) tanks
# 1-227.) banks
# 1-231.) favor
# 1-256.) boats
# 1-263.) marks
# 1-281.) tasks
# 1-292.) naval
# 1-304.) marry
# 1-306.) array
# 1-315.) sharp
# 1-318.) chart
# 1-329.) coach
# 1-332.) ranks
# 1-344.) vocal
# 1-346.) parks
# 1-353.) facts
# 1-362.) grant
# 1-371.) cargo
# 1-378.) watch
# 1-389.) catch
# 1-390.) craft
# 1-391.) camps
# 1-401.) happy
# 1-1475.) carts
# 1-1480.) trash
# 1-1488.) spawn
# 1-1494.) smash
# 1-1498.) hangs
# 1-1511.) masts
# 1-1515.) snack
# 1-1524.) franc
# 1-1529.) palsy
# 1-1530.) scars
# 1-1539.) ranch
# 1-1543.) algal
# 1-1547.) craps
# 1-1565.) strap
# 1-1575.) larva
# 1-1576.) malls
# 1-1606.) manor
# 1-1607.) marsh
# 1-1617.) ovary
# 1-1618.) samba
# 1-1619.) scant
# 1-1621.) slabs
# 1-1630.) kayak
# 1-1632.) matzo
# 1-1635.) soaps
# 1-1638.) tally
# 1-1640.) atlas
# 1-1653.) wraps
# 1-1661.) molar
# 1-1668.) wasps
# 1-1671.) boast
# 1-1681.) toast
# 1-1683.) aorta
# 1-1689.) crank
# 1-1692.) harps
# 1-1699.) roast
# 1-1717.) nasty
# 1-1732.) hasty
# 1-1733.) havoc
# 1-1737.) slack
# 1-1786.) swarm
# 1-1788.) tarot
# 1-1800.) glans
# 1-1825.) grabs
# 1-1832.) salon
# 1-1839.) frank
# 1-1842.) koala
# 1-1848.) assay
# 1-1859.) stabs
# 1-1861.) taxon
# 1-1864.) waltz
# 1-1867.) flask
# 1-1873.) prays
# 1-1881.) crabs
# 1-1887.) jacks
# 1-1892.) swans
# 1-1895.) zakat
# 1-1898.) clams
# 1-1899.) copra
# 1-1907.) harms
# 1-1913.) plank
# 1-1916.) barbs
# 1-1917.) cacao
# 1-1926.) foray
# 1-1940.) shalt
# 1-1947.) wharf
# 1-1952.) baton
# 1-1954.) brawl
# 1-1967.) rafts
# 1-1974.) trays
# 1-1979.) carat
# 1-1990.) polka
# 1-1992.) prank
# 1-1999.) splay
# 1-2004.) barns
# 1-2015.) sagas
# 1-2018.) shaky
# 1-2019.) slant
# 1-2022.) swaps
# 1-2027.) bacon
# 1-2031.) fatwa
# 1-2035.) karst
# 1-2040.) scary
# 1-2049.) clamp
# 1-2067.) boars
# 1-2076.) halts
# 1-2079.) latch
# 1-2083.) satyr
# 1-2084.) scarf
# 1-2088.) total
# 1-2099.) fasts
# 1-2104.) lambs
# 1-2113.) shank
# 1-2125.) canto
# 1-2127.) coals
# 1-2132.) foals
# 1-2134.) gotta
# 1-2141.) mango
# 1-2146.) psalm
# 1-2151.) tango
# 1-2156.) warts
# 1-2167.) chaff
# 1-2177.) graft
# 1-2181.) lawns
# 1-2193.) scalp
# 1-2195.) snaps
# 1-2206.) blanc
# 1-2224.) phyla
# 1-2228.) shoal
# 1-2236.) aback
# 1-2237.) amass
# 1-2239.) baron
# 1-2258.) octal
# 1-2266.) slats
# 1-2267.) spars
# 1-2271.) warms
# 1-2293.) orcas
# 1-2299.) schwa
# 1-2309.) agora
# 1-2326.) hawks
# 1-2329.) karts
# 1-2343.) shawl
# 1-2346.) slams
# 1-2347.) slays
# 1-2348.) stats
# 1-2358.) casks
# 1-2367.) gravy
# 1-3435.) sways
# 1-3438.) tabby
# 1-3439.) talon
# 1-3442.) tangs
# 1-3444.) tarry
# 1-3451.) tsars
# 1-3481.) atman
# 1-3484.) ballo
# 1-3493.) brags
# 1-3500.) bylaw
# 1-3505.) capon
# 1-3509.) chats
# 1-3512.) claps
# 1-3514.) colas
# 1-3550.) fawns
# 1-3583.) jambs
# 1-3588.) karat
# 1-3607.) loamy
# 1-3616.) magna
# 1-3625.) moans
# 1-3627.) moras
# 1-3633.) mylar
# 1-3650.) oscar
# 1-3655.) panna
# 1-3656.) panty
# 1-3666.) platy
# 1-3671.) ragas
# 1-3686.) sally
# 1-3694.) shawm
# 1-3703.) snarl
# 1-3706.) sofas
# 1-3709.) sprat
# 1-3711.) swabs
# 1-3712.) swash
# 1-3732.) vagal
# 1-3738.) whack
# 1-3758.) alway
# 1-3772.) avgas
# 1-3773.) balmy
# 1-3774.) banco
# 1-3788.) bloat
# 1-3799.) brawn
# 1-3806.) campo
# 1-3807.) canny
# 1-3816.) chaps
# 1-3827.) copal
# 1-3830.) cotta
# 1-3833.) croak
# 1-3838.) cyano
# 1-3891.) frays
# 1-3897.) gaffs
# 1-3919.) hamza
# 1-3921.) harks
# 1-3954.) kalon
# 1-3961.) kraal
# 1-3966.) lakhs
# 1-3969.) laths
# 1-3989.) maror
# 1-4029.) pacta
# 1-4033.) parka
# 1-4050.) prana
# 1-4053.) psoas
# 1-4080.) roach
# 1-4090.) salat
# 1-4092.) santa
# 1-4095.) sassy
# 1-4096.) satan
# 1-4101.) scats
# 1-4103.) scram
# 1-4126.) soars
# 1-4129.) solfa
# 1-4132.) spasm
# 1-4147.) tabla
# 1-4148.) tacks
# 1-4150.) tanka
# 1-4168.) togas
# 1-4187.) vamps
# 1-4189.) varna
# 1-4206.) yajna
# 1-4207.) yakka
#
# Guess: woman
# Good placement dictionary {}
# Bad placement dictionary {'a': [0, 3]}
# Bad letters ['u', 'w', 'e', 'n', 'o', 'd', 'i', 'm']
# Top eligible word list:
# 1-36.) carry
# 1-41.) track
# 1-46.) plays
# 1-48.) stars
# 1-69.) staff
# 1-88.) calls
# 1-110.) glass
# 1-161.) shall
# 1-183.) apart
# 1-214.) falls
# 1-281.) tasks
# 1-315.) sharp
# 1-318.) chart
# 1-346.) parks
# 1-353.) facts
# 1-389.) catch
# 1-390.) craft
# 1-401.) happy
# 1-405.) crash
# 1-416.) graph
# 1-463.) paths
# 1-464.) stack
# 1-471.) talks
# 1-472.) balls
# 1-504.) harsh
# 1-532.) papal
# 1-561.) brass
# 1-564.) fatal
# 1-565.) grass
# 1-587.) flash
# 1-632.) shaft
# 1-640.) lacks
# 1-662.) alpha
# 1-696.) lasts
# 1-704.) rally
# 1-708.) salts
# 1-728.) halls
# 1-737.) stays
# 1-746.) tract
# 1-751.) flags
# 1-758.) patch
# 1-763.) fatty
# 1-767.) blast
# 1-770.) start
# 1-819.) class
# 1-820.) batch
# 1-884.) party
# 1-923.) spark
# 1-937.) black
# 1-939.) basal
# 1-945.) crack
# 1-953.) packs
# 1-961.) grasp
# 1-996.) hatch
# 1-1008.) shark
# 1-1023.) clash
# 1-1048.) backs
# 1-1058.) traps
# 1-1134.) chalk
# 1-1152.) pasta
# 1-1165.) flats
# 1-1208.) crazy
# 1-1215.) racks
# 1-1225.) yacht
# 1-1264.) slash
# 1-1267.) stall
# 1-1292.) baths
# 1-1298.) stark
# 1-1309.) casts
# 1-1381.) salty
# 1-1382.) parts
# 1-1395.) flaps
# 1-1422.) sacks
# 1-1432.) clays
# 1-1436.) plaza
# 1-1469.) stalk
# 1-1475.) carts
# 1-1480.) trash
# 1-1529.) palsy
# 1-1530.) scars
# 1-1547.) craps
# 1-1575.) larva
# 1-1621.) slabs
# 1-1630.) kayak
# 1-1638.) tally
# 1-1692.) harps
# 1-1732.) hasty
# 1-1737.) slack
# 1-1825.) grabs
# 1-1859.) stabs
# 1-1867.) flask
# 1-1873.) prays
# 1-1881.) crabs
# 1-1887.) jacks
# 1-1895.) zakat
# 1-1916.) barbs
# 1-1940.) shalt
# 1-1967.) rafts
# 1-1974.) trays
# 1-1979.) carat
# 1-2015.) sagas
# 1-2018.) shaky
# 1-2035.) karst
# 1-2040.) scary
# 1-2076.) halts
# 1-2079.) latch
# 1-2083.) satyr
# 1-2084.) scarf
# 1-2099.) fasts
# 1-2167.) chaff
# 1-2177.) graft
# 1-2193.) scalp
# 1-2224.) phyla
# 1-2236.) aback
# 1-2266.) slats
# 1-2267.) spars
# 1-2329.) karts
# 1-2347.) slays
# 1-2348.) stats
# 1-2358.) casks
# 1-2367.) gravy
# 1-2372.) kvass
# 1-2392.) tapas
# 1-2393.) tasty
# 1-2418.) parry
# 1-2473.) pacts
# 1-2480.) salsa
# 1-2488.) slaps
# 1-2498.) balsa
# 1-2499.) barks
# 1-2503.) calyx
# 1-2531.) pasha
# 1-2543.) scaly
# 1-2567.) falla
# 1-2580.) lavas
# 1-2706.) cabal
# 1-2755.) shack
# 1-2880.) baggy
# 1-2891.) clasp
# 1-2893.) crass
# 1-2911.) halal
# 1-2913.) hypha
# 1-2916.) jazzy
# 1-2930.) patty
# 1-2943.) sacra
# 1-2955.) stash
# 1-2977.) abaca
# 1-2997.) chars
# 1-3029.) hacks
# 1-3062.) palps
# 1-3064.) pasty
# 1-3078.) savvy
# 1-3093.) tarts
# 1-3124.) brash
# 1-3157.) flaky
# 1-3167.) grays
# 1-3186.) larch
# 1-3218.) pasts
# 1-3249.) tacky
# 1-3284.) bract
# 1-3332.) galas
# 1-3333.) galls
# 1-3409.) raspy
# 1-3429.) spats
# 1-3438.) tabby
# 1-3444.) tarry
# 1-3451.) tsars
# 1-3493.) brags
# 1-3509.) chats
# 1-3512.) claps
# 1-3588.) karat
# 1-3666.) platy
# 1-3671.) ragas
# 1-3686.) sally
# 1-3732.) vagal
# 1-3816.) chaps
# 1-3891.) frays
# 1-3897.) gaffs
# 1-3921.) harks
# 1-3961.) kraal
# 1-3966.) lakhs
# 1-3969.) laths
# 1-4029.) pacta
# 1-4033.) parka
# 1-4090.) salat
# 1-4095.) sassy
# 1-4101.) scats
# 1-4147.) tabla
# 1-4148.) tacks
# 1-4207.) yakka
#
# Guess: track
# Good placement dictionary {'r': [1], 'a': [2]}
# Bad placement dictionary {'a': [0, 3]}
# Bad letters ['u', 'w', 'e', 'c', 'n', 't', 'o', 'd', 'k', 'i', 'm']
# Top eligible word list:
# 1-416.) graph
# 1-561.) brass
# 1-565.) grass
# 1-961.) grasp
# 1-1825.) grabs
# 1-1873.) prays
# 1-2367.) gravy
# 1-3124.) brash
# 1-3167.) grays
# 1-3493.) brags
# 1-3891.) frays
#
# Guess: grass
# Good placement dictionary {'r': [1], 'a': [2], 's': [3, 4]}
# Bad placement dictionary {'a': [0, 3]}
# Bad letters ['u', 'w', 'e', 'c', 'n', 't', 'o', 'd', 'g', 'k', 'i', 'm']
# Top eligible word list:
# 1-561.) brass
# 1-1873.) prays
# 1-3124.) brash
# 1-3891.) frays
#
# Guess: brass
# Good placement dictionary {'r': [1], 'a': [2], 's': [3, 4], 'b': [0]}
# Bad placement dictionary {'a': [0, 3]}
# Bad letters ['u', 'w', 'e', 'c', 'n', 't', 'o', 'd', 'g', 'k', 'i', 'm']
# Top eligible word list:
# 1-561.) brass
# 1-3124.) brash

# %%
# Clue = HONEY, Mon 9.16.24
wdl = wd.Wordle()
wdl.set_data()

# Guess #1
wdl.wordle_guess(guess_word='ideas',
                 good_letters=['e'],
                 good_letters_bad_placement=[2])
wu.wordle_solver(wordle=wdl)

# Guess #2
wdl.wordle_guess(guess_word='enjoy',
                 good_letters=['e', 'n', 'o', 'y'],
                 good_letters_bad_placement=[0, 1, 3, None],
                 good_letters_good_placement=[None, None, None, 4])
wu.wordle_solver(wordle=wdl)

# Guess #3
wdl.wordle_guess(guess_word='honey',
                 good_letters=['h', 'o', 'n', 'e', 'y'],
                 good_letters_good_placement=[0, 1, 2, 3, 4])
wu.wordle_solver(wordle=wdl)

# %%
# Clue = ???, Thu 9.26.24
wdl = wd.Wordle()
wdl.set_data()

# Guess #1
wdl.wordle_guess(guess_word='ideas',
                 good_letters=['a'],
                 good_letters_bad_placement=[3])
wu.wordle_solver(wordle=wdl)

# Guess #2
wdl.wordle_guess(guess_word='labor',
                 good_letters=['a'],
                 good_letters_bad_placement=[1])
wu.wordle_solver(wordle=wdl)

# Guess #3
wdl.wordle_guess(guess_word='chant',
                 good_letters=['h', 'a', 'n', 't'],
                 good_letters_good_placement=[1, 2, 3, None],
                 good_letters_bad_placement=[None, None, None, 4])
wu.wordle_solver(wordle=wdl)
