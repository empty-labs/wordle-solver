# %% [markdown]
# # Wordle Solver

# %%
# Local packages
import wordle_data as wd
import wordle_utils as wu

# %% [markdown]
# # Top Wordle Words

# %%
wdl = wd.Wordle()
wdl.set_data()

# Top words
# wu.list_top_wordle_words(wordle=wdl)

# Letter frequency of top words
letter_frequency_dict = wu.collect_top_wordle_words_letter_frequency(wordle=wdl,
                                                                     print_results=False)

wu.determine_optimal_words(wordle=wdl,
                           letter_frequency_dict=letter_frequency_dict,
                           no_repeats=True)
# Out:
# Number of top Wordle words 4214
# Number of eligible Wordle words: 15920
# Most frequent letter count: 2236
# arose 4.063953488372093
# rosea 4.063953488372093
# arise 4.018336314847943
# seria 4.018336314847943
# reais 4.018336314847943
# raise 4.018336314847943
# reals 4.01386404293381
# earls 4.01386404293381
# laser 4.01386404293381
# stare 3.997763864042934
# aster 3.9977638640429336
# rates 3.9977638640429336
# tears 3.9977638640429336
# taser 3.9977638640429336
# aisle 3.936940966010733
# steal 3.9163685152057246
# stela 3.9163685152057246
# stale 3.9163685152057246
# least 3.916368515205724
# tesla 3.916368515205724
# slate 3.916368515205724
# tales 3.916368515205724
# taels 3.916368515205724
# nears 3.9065295169946332
# snare 3.9065295169946332
# earns 3.9065295169946332
# aeons 3.8752236135957063
# anise 3.829606440071556
# dares 3.8282647584973164
# reads 3.8282647584973164
# lanes 3.825134168157424
# leans 3.825134168157424
# antes 3.8090339892665472
# ...

# %%
# Clue = OWNER, Sat 9.7.24
wdl = wd.Wordle()
wdl.set_data()

wdl.wordle_guess(guess_word='pound',
                 good_letters=['o', 'n'],
                 good_letters_bad_placement=[1, 3])
wu.wordle_solver(wordle=wdl)

wdl.wordle_guess(guess_word='dawgs',
                 good_letters=['w'],
                 good_letters_bad_placement=[2])
wu.wordle_solver(wordle=wdl)

wdl.wordle_guess(guess_word='known',
                 good_letters=['n', 'o', 'w', 'n'],
                 good_letters_bad_placement=[1, 2, 3, 4])
wu.wordle_solver(wordle=wdl)

wdl.wordle_guess(guess_word='raven',
                 good_letters=['r', 'e', 'n'],
                 good_letters_bad_placement=[0, None, 4],
                 good_letters_good_placement=[None, 3, None])
wu.wordle_solver(wordle=wdl)

wdl.wordle_guess(guess_word='owned',
                 good_letters=['o', 'w', 'n', 'e'],
                 good_letters_good_placement=[0, 1, 2, 3])
wu.wordle_solver(wordle=wdl)
# Out:
# Number of top Wordle words 4214
# Number of eligible Wordle words: 15920
#
# Guess: pound
# Good placement dictionary {}
# Bad placement dictionary {'o': [1], 'n': [3]}
# Bad letters ['d', 'p', 'u']
# Top eligible word list:
# 1-77.) minor
# 2-159.) grown
# 3-234.) brown
# 4-274.) honor
# 5-278.) ocean
# 6-279.) owner
# 7-351.) crown
# 8-419.) enjoy
# 9-425.) organ
# 10-429.) knows
# 11-447.) known
# 12-461.) often
# 13-670.) canon
# 14-675.) onset
# 15-702.) flown
# 16-720.) ozone
# 17-783.) bison
# 18-874.) sworn
# 19-908.) knots
# 20-909.) blown
# 21-990.) tenor
# 22-1015.) boron
# 23-1092.) knock
# 24-1150.) colon
# 25-1232.) wagon
# 26-1251.) onion
# 27-1262.) envoy
# 28-1275.) lemon
# 29-1281.) banjo
# 30-1346.) nylon
# 31-1366.) argon
# 32-1404.) clown
# 33-1534.) anion
# 34-1554.) snowy
# 35-1594.) venom
# 36-1606.) manor
# 37-1673.) canoe
# 38-1749.) nomen
# 39-1770.) xenon
# 40-1813.) arson
# 41-1826.) groin
# 42-1832.) salon
# 43-1861.) taxon
# 44-1896.) boson
# ...

# %%
# Clue = DRAWN, Sun 9.8.24
wdl = wd.Wordle()
wdl.set_data()

wdl.wordle_guess(guess_word='ideas',
                 good_letters=['d', 'a'],
                 good_letters_bad_placement=[1, 3])
wu.wordle_solver(wordle=wdl)

wdl.wordle_guess(guess_word='draft',
                 good_letters=['d', 'r', 'a'],
                 good_letters_good_placement=[0, 1, 2])
wu.wordle_solver(wordle=wdl)

wdl.wordle_guess(guess_word='drawn',
                 good_letters=['d', 'r', 'a', 'w', 'n'],
                 good_letters_good_placement=[0, 1, 2, 3, 4])
wu.wordle_solver(wordle=wdl)

# %%
# Clue = DEBIT, Mon 9.9.24
wdl = wd.Wordle()
wdl.set_data()

wdl.wordle_guess(guess_word='ideas',
                 good_letters=['i', 'd', 'e'],
                 good_letters_bad_placement=[0, 1, 2])
wu.wordle_solver(wordle=wdl)

wdl.wordle_guess(guess_word='tried',
                 good_letters=['t', 'i', 'e', 'd'],
                 good_letters_bad_placement=[0, 2, 3, 4])
wu.wordle_solver(wordle=wdl)

wdl.wordle_guess(guess_word='debit',
                 good_letters=['d', 'e', 'b', 'i', 't'],
                 good_letters_good_placement=[0, 1, 2, 3, 4])
wu.wordle_solver(wordle=wdl)

# %%
# Clue = REBEL, Tue 9.10.24
wdl = wd.Wordle()
wdl.set_data()

wdl.wordle_guess(guess_word='ideas',
                 good_letters=['e'],
                 good_letters_bad_placement=[2])
wu.wordle_solver(wordle=wdl)

# TODO Need to fix good letter bad placement based on this guess
wdl.wordle_guess(guess_word='cover',
                 good_letters=['e', 'r'],
                 good_letters_bad_placement=[None, 4],
                 good_letters_good_placement=[3, None])
wu.wordle_solver(wordle=wdl)

wdl.wordle_guess(guess_word='threw',
                 good_letters=['e', 'r'],
                 good_letters_bad_placement=[None, 2],
                 good_letters_good_placement=[3, None])
wu.wordle_solver(wordle=wdl)

wdl.wordle_guess(guess_word='green',
                 good_letters=['e', 'r'],
                 good_letters_bad_placement=[2, 1],
                 good_letters_good_placement=[3, None])
wu.wordle_solver(wordle=wdl)

wdl.wordle_guess(guess_word='rebel',
                 good_letters=['r', 'e', 'b', 'e', 'l'],
                 good_letters_good_placement=[0, 1, 2, 3, 4])
wu.wordle_solver(wordle=wdl)

# %%
# Clue = BRASS, Thu 9.12.24
wdl = wd.Wordle()
wdl.set_data()

wdl.wordle_guess(guess_word='adieu',
                 good_letters=['a'],
                 good_letters_bad_placement=[0])
wu.wordle_solver(wordle=wdl)

wdl.wordle_guess(guess_word='woman',
                 good_letters=['a'],
                 good_letters_bad_placement=[3])
wu.wordle_solver(wordle=wdl)

wdl.wordle_guess(guess_word='track',
                 good_letters=['r', 'a'],
                 good_letters_good_placement=[1, 2])
wu.wordle_solver(wordle=wdl)

wdl.wordle_guess(guess_word='grass',
                 good_letters=['r', 'a', 's', 's'],
                 good_letters_good_placement=[1, 2, 3, 4])
wu.wordle_solver(wordle=wdl)

wdl.wordle_guess(guess_word='brass',
                 good_letters=['b', 'r', 'a', 's', 's'],
                 good_letters_good_placement=[0, 1, 2, 3, 4])
wu.wordle_solver(wordle=wdl)

# %%
# Clue = HONEY, Mon 9.16.24
wdl = wd.Wordle()
wdl.set_data()

wdl.wordle_guess(guess_word='ideas',
                 good_letters=['e'],
                 good_letters_bad_placement=[2])
wu.wordle_solver(wordle=wdl)

wdl.wordle_guess(guess_word='enjoy',
                 good_letters=['e', 'n', 'o', 'y'],
                 good_letters_bad_placement=[0, 1, 3, None],
                 good_letters_good_placement=[None, None, None, 4])
wu.wordle_solver(wordle=wdl)

wdl.wordle_guess(guess_word='honey',
                 good_letters=['h', 'o', 'n', 'e', 'y'],
                 good_letters_good_placement=[0, 1, 2, 3, 4])
wu.wordle_solver(wordle=wdl)

# %%
# Clue = ???, Thu 9.26.24
wdl = wd.Wordle()
wdl.set_data()

wdl.wordle_guess(guess_word='ideas',
                 good_letters=['a'],
                 good_letters_bad_placement=[3])
wu.wordle_solver(wordle=wdl)

wdl.wordle_guess(guess_word='labor',
                 good_letters=['a'],
                 good_letters_bad_placement=[1])
wu.wordle_solver(wordle=wdl)

wdl.wordle_guess(guess_word='chant',
                 good_letters=['h', 'a', 'n', 't'],
                 good_letters_good_placement=[1, 2, 3, None],
                 good_letters_bad_placement=[None, None, None, 4])
wu.wordle_solver(wordle=wdl)
